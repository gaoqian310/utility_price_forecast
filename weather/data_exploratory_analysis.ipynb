# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Specify the folder path where your CSV files are located
folder_path = 'aggregated_weather_data'

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.lower().endswith('_aggregated_weather.csv')]

# %%
# Read each CSV file and create separate plots
for csv_file in csv_files:
    city_name = os.path.splitext(csv_file)[0].split('_')[0]  # Extract city name
    df = pd.read_csv(os.path.join(folder_path, csv_file))
    
    # Summary statistics
    print(f"Summary statistics for {city_name}:")
    print(df.describe())
    
    # Heatmap to visualize missing values
    plt.figure(figsize=(8, 6))
    sns.heatmap(df.isnull(), cmap='coolwarm', cbar=False)
    plt.title("Missing Values Heatmap for {city_name}:")
    plt.show()

    # Time series plot for temperature
    plt.figure(figsize=(10, 6))
    df['Date/Time (LST)'] = pd.to_datetime(df['Date/Time (LST)'])
    df.set_index('Date/Time (LST)', inplace=True)
    df['Temp (°C)'].plot()
    plt.xlabel("Date")
    plt.ylabel("Temperature (°C)")
    plt.title(f"Temperature Variation in {city_name}")
    plt.grid(True)
    plt.show()

    # Dew Point Temperature Variation
    plt.figure(figsize=(10, 6))
    df['Dew Point Temp (°C)'].plot()
    plt.xlabel("Date")
    plt.ylabel("Dew Point Temperature (°C)")
    plt.title(f"Dew Point Temperature Variation in {city_name}")
    plt.grid(True)
    plt.show()

    # Relative Humidity Trends
    plt.figure(figsize=(10, 6))
    df.groupby('Month')['Rel Hum (%)'].mean().plot(kind='bar')
    plt.xlabel("Month")
    plt.ylabel("Relative Humidity (%)")
    plt.title(f"Relative Humidity Trends in {city_name}")
    plt.grid(True)
    plt.show()

    # Pressure Trends
    plt.figure(figsize=(10, 6))
    df['Stn Press (kPa)'].plot()
    plt.xlabel("Date")
    plt.ylabel("Stn Press (kPa)")
    plt.title(f"Station Pressure Variation in {city_name}")
    plt.grid(True)
    plt.show()

     # Wind Chill Trends
    plt.figure(figsize=(10, 6))
    df.groupby('Month')['Wind Chill'].mean().plot(kind='bar')
    plt.xlabel("Month")
    plt.ylabel("Wind Chill")
    plt.title(f"Wind Chill Trends in {city_name}")
    plt.grid(True)
    plt.show()

    print("\n")  # Add a separator between cities
# Out:
# Summary statistics for Calgary:
#        Longitude (x)  Latitude (y)  Climate ID          Year         Month  \
# count       88848.00      88848.00     88848.0  88848.000000  88848.000000
# mean         -114.01         51.12   3031092.0   2018.574014      6.454079
# std             0.00          0.00         0.0      2.922258      3.476719
# min          -114.01         51.12   3031092.0   2014.000000      1.000000
# 25%          -114.01         51.12   3031092.0   2016.000000      3.000000
# 50%          -114.01         51.12   3031092.0   2019.000000      6.000000
# 75%          -114.01         51.12   3031092.0   2021.000000      9.000000
# max          -114.01         51.12   3031092.0   2024.000000     12.000000
#
#                 Day     Temp (°C)  Dew Point Temp (°C)   Rel Hum (%)  \
# count  88848.000000  88738.000000         88735.000000  88737.000000
# mean      15.700702      5.179041            -3.001705     60.277742
# std        8.796327     11.703701             9.532389     20.754197
# min        1.000000    -36.200000           -40.400000      8.000000
# 25%        8.000000     -2.000000            -9.000000     43.000000
# 50%       16.000000      5.900000            -2.800000     62.000000
# 75%       23.000000     13.800000             4.600000     78.000000
# max       31.000000     36.400000            24.000000    100.000000
#
#        Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# count        85881.000000     88738.000000     88740.000000     88739.000000
# mean            21.171412        13.743988        31.188523        88.810451
# std             10.268123         8.721834        20.243513         0.703645
# min              0.000000         0.000000         0.000000        85.610000
# 25%             15.000000         8.000000        16.100000        88.380000
# 50%             21.000000        12.000000        24.100000        88.860000
# 75%             30.000000        18.000000        48.300000        89.290000
# max             36.000000        69.000000        80.500000        91.360000
#
#          Wind Chill
# count  26475.000000
# mean     -13.861794
# std        9.060901
# min      -47.000000
# 25%      -19.000000
# 50%      -11.000000
# 75%       -7.000000
# max        0.000000
# Summary statistics for Edmonton:
#        Longitude (x)  Latitude (y)  Climate ID          Year         Month  \
# count   8.784200e+04  8.784200e+04     87842.0  87842.000000  87842.000000
# mean   -1.135800e+02  5.331000e+01   3012216.0   2018.603493      6.393548
# std     4.263281e-14  7.105468e-15         0.0      2.925858      3.449666
# min    -1.135800e+02  5.331000e+01   3012216.0   2014.000000      1.000000
# 25%    -1.135800e+02  5.331000e+01   3012216.0   2016.000000      3.000000
# 50%    -1.135800e+02  5.331000e+01   3012216.0   2019.000000      6.000000
# 75%    -1.135800e+02  5.331000e+01   3012216.0   2021.000000      9.000000
# max    -1.135800e+02  5.331000e+01   3012216.0   2024.000000     12.000000
#
#                 Day     Temp (°C)  Dew Point Temp (°C)   Rel Hum (%)  \
# count  87842.000000  87817.000000         87817.000000  87816.000000
# mean      15.670317      3.069554            -2.376038     71.200977
# std        8.791627     12.760919            11.203877     18.995588
# min        1.000000    -45.700000           -49.900000      8.000000
# 25%        8.000000     -5.200000            -9.000000     60.000000
# 50%       16.000000      3.400000            -1.800000     75.000000
# 75%       23.000000     12.900000             6.500000     86.000000
# max       31.000000     33.400000            22.700000    100.000000
#
#        Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# count        86118.000000     87812.000000     87821.000000     87818.000000
# mean            21.028856        13.519189        25.262376        92.936104
# std              8.891887         7.859993         7.874854         0.767481
# min              0.000000         0.000000         0.000000        89.380000
# 25%             14.000000         8.000000        24.100000        92.470000
# 50%             20.000000        12.000000        24.100000        92.950000
# 75%             29.000000        18.000000        32.200000        93.420000
# max             36.000000        73.000000        80.500000        96.040000
#
#          Wind Chill
# count  33710.000000
# mean     -15.426936
# std        9.681994
# min      -58.000000
# 25%      -21.000000
# 50%      -13.000000
# 75%       -8.000000
# max        0.000000
# Summary statistics for Fort McMurray:
#        Longitude (x)  Latitude (y)  Climate ID          Year         Month  \
# count   8.882400e+04  8.882400e+04     88824.0  88824.000000  88824.000000
# mean   -1.112200e+02  5.665000e+01   3062697.0   2018.572548      6.455282
# std     1.421093e-14  1.421093e-14         0.0      2.921291      3.476417
# min    -1.112200e+02  5.665000e+01   3062697.0   2014.000000      1.000000
# 25%    -1.112200e+02  5.665000e+01   3062697.0   2016.000000      3.000000
# 50%    -1.112200e+02  5.665000e+01   3062697.0   2019.000000      6.000000
# 75%    -1.112200e+02  5.665000e+01   3062697.0   2021.000000      9.000000
# max    -1.112200e+02  5.665000e+01   3062697.0   2024.000000     12.000000
#
#                 Day     Temp (°C)  Dew Point Temp (°C)   Rel Hum (%)  \
# count  88824.000000  88350.000000         87773.000000  88034.000000
# mean      15.699811      1.603591            -4.136190     69.940648
# std        8.797348     14.448151            12.609491     19.373388
# min        1.000000    -42.500000           -46.700000     12.000000
# 25%        8.000000     -8.900000           -12.400000     57.000000
# 50%       16.000000      2.700000            -3.000000     74.000000
# 75%       23.000000     13.300000             6.500000     85.000000
# max       31.000000     39.800000            20.500000    100.000000
#
#        Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# count        81661.000000     88624.000000     88596.000000     88598.000000
# mean            20.059882        12.327688        14.946281        96.979490
# std              9.713717         6.973555         3.374991         0.904276
# min              1.000000         0.000000         0.000000        93.580000
# 25%             11.000000         8.000000        16.100000        96.390000
# 50%             22.000000        11.000000        16.100000        96.960000
# 75%             29.000000        17.000000        16.100000        97.540000
# max             36.000000        59.000000        16.100000       100.520000
#
#          Wind Chill
# count  36706.000000
# mean     -17.905874
# std       10.264320
# min      -53.000000
# 25%      -25.000000
# 50%      -16.000000
# 75%       -9.000000
# max       -1.000000
# Summary statistics for Grande Prairie:
#        Longitude (x)  Latitude (y)  Climate ID          Year         Month  \
# count   8.882400e+04  8.882400e+04     88824.0  88824.000000  88824.000000
# mean   -1.188800e+02  5.518000e+01   3072921.0   2018.572548      6.455282
# std     8.526561e-14  3.552734e-14         0.0      2.921291      3.476417
# min    -1.188800e+02  5.518000e+01   3072921.0   2014.000000      1.000000
# 25%    -1.188800e+02  5.518000e+01   3072921.0   2016.000000      3.000000
# 50%    -1.188800e+02  5.518000e+01   3072921.0   2019.000000      6.000000
# 75%    -1.188800e+02  5.518000e+01   3072921.0   2021.000000      9.000000
# max    -1.188800e+02  5.518000e+01   3072921.0   2024.000000     12.000000
#
#                 Day     Temp (°C)  Dew Point Temp (°C)   Rel Hum (%)  \
# count  88824.000000  88771.000000         88769.000000  88767.000000
# mean      15.699811      2.531204            -3.086394     70.335316
# std        8.797348     13.191698            11.153497     18.804530
# min        1.000000    -44.300000           -48.400000      7.000000
# 25%        8.000000     -5.900000            -9.300000     58.000000
# 50%       16.000000      3.500000            -1.800000     74.000000
# 75%       23.000000     12.700000             5.600000     85.000000
# max       31.000000     41.100000            20.500000    100.000000
#
#        Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# count        84968.000000     88770.000000     88776.000000     88769.000000
# mean            21.499965        13.294784        34.320218        93.528780
# std             10.136152         9.810859        11.576717         0.795992
# min              0.000000         0.000000         0.000000        90.210000
# 25%             13.000000         6.000000        32.200000        93.050000
# 50%             24.000000        10.000000        40.200000        93.530000
# 75%             29.000000        18.000000        40.200000        94.010000
# max             36.000000        95.000000        80.500000        96.870000
#
#          Wind Chill
# count  32334.000000
# mean     -15.716614
# std        9.888623
# min      -56.000000
# 25%      -22.000000
# 50%      -14.000000
# 75%       -8.000000
# max        0.000000
# Summary statistics for Lethbridge:
#        Longitude (x)  Latitude (y)  Climate ID          Year         Month  \
# count   8.882200e+04      88822.00     88822.0  88822.000000  88822.000000
# mean   -1.128000e+02         49.63   3033875.0   2018.572628      6.455405
# std     2.842187e-14          0.00         0.0      2.921275      3.476360
# min    -1.128000e+02         49.63   3033875.0   2014.000000      1.000000
# 25%    -1.128000e+02         49.63   3033875.0   2016.000000      3.000000
# 50%    -1.128000e+02         49.63   3033875.0   2019.000000      6.000000
# 75%    -1.128000e+02         49.63   3033875.0   2021.000000      9.000000
# max    -1.128000e+02         49.63   3033875.0   2024.000000     12.000000
#
#                 Day     Temp (°C)  Dew Point Temp (°C)   Rel Hum (%)  \
# count  88822.000000  87933.000000         87613.000000  87665.000000
# mean      15.700142      5.991970            -1.534243     63.540124
# std        8.797170     12.137133             9.410952     21.447553
# min        1.000000    -41.000000           -45.200000      6.000000
# 25%        8.000000     -0.900000            -6.500000     47.000000
# 50%       16.000000      6.600000            -0.900000     66.000000
# 75%       23.000000     14.400000             5.500000     82.000000
# max       31.000000     40.000000            21.300000    100.000000
#
#        Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# count        83298.000000     87941.000000     87827.000000      87921.00000
# mean            21.597325        19.384690        15.085130         90.72884
# std              8.317318        12.362018         3.244809          0.68990
# min              1.000000         0.000000         0.000000         87.45000
# 25%             18.000000        11.000000        16.100000         90.30000
# 50%             24.000000        17.000000        16.100000         90.75000
# 75%             26.000000        26.000000        16.100000         91.18000
# max             36.000000        87.000000        16.100000         93.53000
#
#          Wind Chill
# count  23961.000000
# mean     -15.093193
# std        9.328835
# min      -53.000000
# 25%      -20.000000
# 50%      -13.000000
# 75%       -8.000000
# max       -1.000000
# Summary statistics for Medicine Hat:
#        Longitude (x)  Latitude (y)  Climate ID          Year         Month  \
# count   8.882400e+04  8.882400e+04     88824.0  88824.000000  88824.000000
# mean   -1.107200e+02  5.002000e+01   3034479.0   2018.572548      6.455282
# std     1.421093e-14  2.131640e-14         0.0      2.921291      3.476417
# min    -1.107200e+02  5.002000e+01   3034479.0   2014.000000      1.000000
# 25%    -1.107200e+02  5.002000e+01   3034479.0   2016.000000      3.000000
# 50%    -1.107200e+02  5.002000e+01   3034479.0   2019.000000      6.000000
# 75%    -1.107200e+02  5.002000e+01   3034479.0   2021.000000      9.000000
# max    -1.107200e+02  5.002000e+01   3034479.0   2024.000000     12.000000
#
#                 Day     Temp (°C)  Dew Point Temp (°C)   Rel Hum (%)  \
# count  88824.000000  88128.000000         88107.000000  88108.000000
# mean      15.699811      6.187407            -1.264418     64.517070
# std        8.797348     13.030071             9.765256     21.825907
# min        1.000000    -40.800000           -44.900000      9.000000
# 25%        8.000000     -1.900000            -6.300000     48.000000
# 50%       16.000000      6.600000            -0.500000     69.000000
# 75%       23.000000     15.700000             6.200000     82.000000
# max       31.000000     39.500000            19.700000    100.000000
#
#        Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# count        81621.000000     88020.000000     86051.000000     88127.000000
# mean            20.576286        15.220325        15.302983        93.071348
# std              8.993955         9.327158         2.834811         0.743865
# min              1.000000         0.000000         0.000000        89.650000
# 25%             17.000000         8.000000        16.100000        92.600000
# 50%             22.000000        13.000000        16.100000        93.070000
# 75%             26.000000        21.000000        16.100000        93.540000
# max             36.000000        80.000000        16.100000        96.160000
#
#          Wind Chill
# count  25699.000000
# mean     -14.713452
# std        9.231338
# min      -54.000000
# 25%      -20.000000
# 50%      -12.000000
# 75%       -7.000000
# max       -1.000000
# Summary statistics for Red Deer:
#        Longitude (x)  Latitude (y)    Climate ID          Year         Month  \
# count   8.607800e+04  8.607800e+04  8.607800e+04  86078.000000  86078.000000
# mean   -1.138900e+02  5.218000e+01  3.025482e+06   2018.729571      6.581566
# std     5.684375e-14  2.842187e-14  1.399531e+00      2.850274      3.451675
# min    -1.138900e+02  5.218000e+01  3.025481e+06   2014.000000      1.000000
# 25%    -1.138900e+02  5.218000e+01  3.025481e+06   2016.000000      4.000000
# 50%    -1.138900e+02  5.218000e+01  3.025481e+06   2019.000000      7.000000
# 75%    -1.138900e+02  5.218000e+01  3.025484e+06   2021.000000     10.000000
# max    -1.138900e+02  5.218000e+01  3.025484e+06   2024.000000     12.000000
#
#                 Day     Temp (°C)  Dew Point Temp (°C)   Rel Hum (%)  \
# count  86078.000000  84316.000000         84304.000000  84291.000000
# mean      15.717164      3.202601            -2.376091     70.853116
# std        8.800157     12.560154            10.849725     19.563033
# min        1.000000    -43.500000           -47.300000      8.000000
# 25%        8.000000     -5.000000            -8.900000     58.000000
# 50%       16.000000      3.900000            -1.800000     75.000000
# 75%       23.000000     12.800000             6.400000     86.000000
# max       31.000000     35.800000            21.200000    100.000000
#
#        Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# count        79053.000000     84204.000000     84047.000000     84287.000000
# mean            20.697886        12.016092        18.646217        90.930589
# std              9.264704         7.657137         6.465955         0.726224
# min              1.000000         0.000000         0.000000        87.780000
# 25%             15.000000         7.000000        16.100000        90.490000
# 50%             20.000000        10.000000        19.300000        90.970000
# 75%             29.000000        16.000000        24.100000        91.410000
# max             36.000000        81.000000        80.500000        93.740000
#
#          Wind Chill
# count  31005.000000
# mean     -14.831414
# std        9.345712
# min      -53.000000
# 25%      -21.000000
# 50%      -13.000000
# 75%       -7.000000
# max       -1.000000

# %%
# Initialize a dictionary to store common weather conditions
common_weather = {}

# Read each CSV file and analyze weather conditions
for csv_file in csv_files:
    city_name = os.path.splitext(csv_file)[0].split('_')[0]  # Extract city name
    df = pd.read_csv(os.path.join(folder_path, csv_file))

    # Combine "clear" and "mainly clear" into a single category
    df['Weather'] = df['Weather'].replace({'Mainly Clear': 'Clear'})

    # Combine "cloudy" and "mainly cloudy" into a single category
    df['Weather'] = df['Weather'].replace({'Mostly Cloudy': 'Cloudy'})
    
    # Count occurrences of each weather condition
    weather_counts = df['Weather'].value_counts()

    # Get the top 10 most common weather conditions
    top_10_weather = weather_counts.nlargest(10)
    
    # Store the result in the dictionary
    common_weather[city_name] = top_10_weather

    # Plot the most common weather
    plt.figure(figsize=(8, 5))
    top_10_weather.plot(kind='bar', color='skyblue')
    plt.xlabel("Weather Condition")
    plt.ylabel("Frequency")
    plt.title(f"Most Common Weather in {city_name}")
    plt.grid(axis='y')
    plt.show()

# Print the summary
for city, weather in common_weather.items():
    print(f"Most common weather in {city}: {weather}")
# Out:
# Most common weather in Calgary: Weather
# Cloudy          12457
# Clear           11484
# Snow             3685
# Fog              2562
# Smoke            2163
# Ice Crystals     1118
# Snow,Fog         1108
# Rain             1043
# Rain Showers      944
# Rain,Fog          718
# Name: count, dtype: int64
# Most common weather in Edmonton: Weather
# Cloudy               14668
# Clear                 8940
# Snow                  6045
# Rain Showers          1744
# Fog                   1623
# Snow,Blowing Snow     1304
# Rain                  1262
# Smoke                  783
# Ice Crystals           571
# Blowing Snow           526
# Name: count, dtype: int64
# Most common weather in Fort McMurray: Weather
# Snow                  9149
# Rain                  2476
# Fog                   1447
# Haze                  1413
# Rain,Fog               451
# Moderate Rain          187
# Freezing Fog           164
# Moderate Rain,Fog      123
# Thunderstorms,Rain      45
# Thunderstorms           41
# Name: count, dtype: int64
# Most common weather in Grande Prairie: Weather
# Cloudy               13904
# Clear                10385
# Snow                  5367
# Rain Showers          1759
# Fog                   1682
# Rain                  1345
# Smoke                 1184
# Snow,Blowing Snow      928
# Freezing Fog           829
# Blowing Snow           733
# Name: count, dtype: int64
# Most common weather in Lethbridge: Weather
# Snow                 5251
# Rain                 2003
# Fog                  1470
# Haze                  937
# Rain,Fog              368
# Freezing Fog          236
# Moderate Snow         118
# Thunderstorms          74
# Moderate Rain          71
# Moderate Rain,Fog      67
# Name: count, dtype: int64
# Most common weather in Medicine Hat: Weather
# Snow                  4773
# Rain                  1916
# Fog                   1300
# Haze                   789
# Rain,Fog               233
# Freezing Fog           206
# Moderate Rain          103
# Moderate Snow           47
# Thunderstorms,Rain      46
# Thunderstorms           44
# Name: count, dtype: int64
# Most common weather in Red Deer: Weather
# Cloudy               8920
# Clear                6248
# Snow                 5123
# Fog                  3210
# Rain                 1499
# Rain Showers          727
# Smoke                 717
# Haze                  634
# Snow,Blowing Snow     583
# Freezing Fog          503
# Name: count, dtype: int64
