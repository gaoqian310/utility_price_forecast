# %% [markdown]
# # This code is not working yet...

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the CSV file into a DataFrame object
df = pd.read_csv("https://dd.weather.gc.ca/climate/observations/hourly/csv/AB/climate_hourly_AB_3031092_2020_P1H.csv",encoding = "cp1252")
# df = pd.read_csv("weather_data/Calgary_2020.csv",encoding = "cp1252")

# %%
# View the first 5 rows of the DataFrame
df.head()
# Out:
#    Longitude (x)  Latitude (y)    Station Name  Climate ID   Date/Time (LST)  \
# 0        -114.01         51.12  CALGARY INTL A     3031092  2020-01-01 00:00
# 1        -114.01         51.12  CALGARY INTL A     3031092  2020-01-01 01:00
# 2        -114.01         51.12  CALGARY INTL A     3031092  2020-01-01 02:00
# 3        -114.01         51.12  CALGARY INTL A     3031092  2020-01-01 03:00
# 4        -114.01         51.12  CALGARY INTL A     3031092  2020-01-01 04:00
#
#    Year  Month  Day Time (LST)  Temp (°C)  ...  Wind Spd Flag  \
# 0  2020      1    1      00:00        2.2  ...            NaN
# 1  2020      1    1      01:00        1.4  ...            NaN
# 2  2020      1    1      02:00        2.5  ...            NaN
# 3  2020      1    1      03:00        1.4  ...            NaN
# 4  2020      1    1      04:00       -0.3  ...            NaN
#
#    Visibility (km)  Visibility Flag  Stn Press (kPa)  Stn Press Flag  Hmdx  \
# ...

# %%
# View the summary statistics of the numerical columns
df.describe()
# Out:
#        Longitude (x)  Latitude (y)  Climate ID    Year        Month  \
# count        8784.00       8784.00      8784.0  8784.0  8784.000000
# mean         -114.01         51.12   3031092.0  2020.0     6.513661
# std             0.00          0.00         0.0     0.0     3.451430
# min          -114.01         51.12   3031092.0  2020.0     1.000000
# 25%          -114.01         51.12   3031092.0  2020.0     4.000000
# 50%          -114.01         51.12   3031092.0  2020.0     7.000000
# 75%          -114.01         51.12   3031092.0  2020.0    10.000000
# max          -114.01         51.12   3031092.0  2020.0    12.000000
#
#                Day    Temp (°C)  Temp Flag  Dew Point Temp (°C)  \
# count  8784.000000  8775.000000        0.0          8776.000000
# mean     15.756831     5.129333        NaN            -2.912432
# std       8.812031    11.241545        NaN             9.375795
# min       1.000000   -32.200000        NaN           -35.800000
# ...

# %%
# View the data types and missing values of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Longitude (x)        8784 non-null   float64
#  1   Latitude (y)         8784 non-null   float64
#  2   Station Name         8784 non-null   object
#  3   Climate ID           8784 non-null   int64
#  4   Date/Time (LST)      8784 non-null   object
#  5   Year                 8784 non-null   int64
#  6   Month                8784 non-null   int64
#  7   Day                  8784 non-null   int64
#  8   Time (LST)           8784 non-null   object
#  9   Temp (°C)            8775 non-null   float64
#  10  Temp Flag            0 non-null      float64
#  11  Dew Point Temp (°C)  8776 non-null   float64
#  12  Dew Point Temp Flag  0 non-null      float64
#  13  Rel Hum (%)          8776 non-null   float64
#  14  Rel Hum Flag         0 non-null      float64
# ...

# %%
# Remove empty columns
df = df.drop(columns=['Temp Flag','Dew Point Temp Flag','Rel Hum Flag','Precip. Amount (mm)','Precip. Amount Flag','Wind Dir Flag',
                      'Wind Spd Flag','Visibility Flag','Stn Press Flag','Hmdx','Hmdx Flag','Wind Chill Flag'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Longitude (x)        8784 non-null   float64
#  1   Latitude (y)         8784 non-null   float64
#  2   Station Name         8784 non-null   object
#  3   Climate ID           8784 non-null   int64
#  4   Date/Time (LST)      8784 non-null   object
#  5   Year                 8784 non-null   int64
#  6   Month                8784 non-null   int64
#  7   Day                  8784 non-null   int64
#  8   Time (LST)           8784 non-null   object
#  9   Temp (°C)            8775 non-null   float64
#  10  Dew Point Temp (°C)  8776 non-null   float64
#  11  Rel Hum (%)          8776 non-null   float64
#  12  Wind Dir (10s deg)   8422 non-null   float64
#  13  Wind Spd (km/h)      8775 non-null   float64
#  14  Visibility (km)      8776 non-null   float64
# ...

# %%
# Convert the date columns to datetime format
df["Date"] = pd.to_datetime(df[["Year", "Month", "Day"]])

# Convert the "Time (LST)" column to datetime objects
df["Time"] = pd.to_datetime(df["Time (LST)"], format="%H:%M").dt.time

# Filter data for peak hours (16:00-21:00) on the same date
peak_hour_df = df[(df["Time"] >= pd.to_datetime("16:00").time()) & (df["Time"] < pd.to_datetime("21:00").time())]

# Calculate the average temperature during peak hours
peak_hour_average_temp = peak_hour_df.groupby("Date")["Temp (°C)"].mean()

# Filter data for off-peak hours (21:00-16:00 next day, including the date+1)
offpeak_hour_df = df[((df["Time"] >= pd.to_datetime("21:00").time()) | (df["Time"] < pd.to_datetime("16:00").time()))]

# Calculate the average temperature during off-peak hours
offpeak_hour_average_temp = offpeak_hour_df.groupby("Date")["Temp (°C)"].mean()

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(peak_hour_average_temp, label="Peak Hours (16:00-21:00)", color="r")
plt.plot(offpeak_hour_average_temp, label="Off-Peak Hours (21:00-16:00 next day)", color="b")
plt.xlabel("Date")
plt.ylabel("Average Temperature (°C)")
plt.title("Average Temperature during Peak and Off-Peak Hours")
plt.grid()
plt.legend()
plt.show()

# %%
# Convert the date columns to datetime format
df["Date"] = pd.to_datetime(df[["Year", "Month", "Day"]])

# Convert the "Time (LST)" column to datetime objects
df["Time"] = pd.to_datetime(df["Time (LST)"], format="%H:%M").dt.time

# Filter data for January
january_df = df[df["Date"].dt.month == 1]

# Calculate the average temperature during peak hours in January
january_peak_hour_df = january_df[(january_df["Time"] >= pd.to_datetime("16:00").time()) & (january_df["Time"] < pd.to_datetime("21:00").time())]
january_peak_hour_average_temp = january_peak_hour_df.groupby("Date")["Temp (°C)"].mean()

# Calculate the average temperature during off-peak hours in January
january_offpeak_hour_df = january_df[((january_df["Time"] >= pd.to_datetime("21:00").time()) | (january_df["Time"] < pd.to_datetime("16:00").time()))]
january_offpeak_hour_average_temp = january_offpeak_hour_df.groupby("Date")["Temp (°C)"].mean()

# Plot the data for January
plt.figure(figsize=(10, 6))
plt.plot(january_peak_hour_average_temp, label="Peak Hours (16:00-21:00)", color="r")
plt.plot(january_offpeak_hour_average_temp, label="Off-Peak Hours (21:00-16:00 next day)", color="b")
plt.xlabel("Date and Time")
plt.ylabel("Average Temperature (°C)")
plt.title("Average Temperature during Peak and Off-Peak Hours in January")
plt.grid()
plt.legend()
plt.show()

# %%
## Convert the 'Date/Time (LST)' column to datetime format
df['Date/Time (LST)'] = pd.to_datetime(df['Date/Time (LST)'])

# Plot the time series of temperature
plt.figure(figsize=(10, 6))
plt.plot(df['Date/Time (LST)'], df['Temp (°C)'], color='b', label='Temperature')
plt.xlabel("DATETIME (LST)")
plt.ylabel("Temperature (°C)")
plt.title("Temperature vs. DATETIME (LST)")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Assuming you have already loaded the data into the 'df' DataFrame

# Extract the date and time components
df['Date'] = df['Date/Time (LST)'].dt.date
df['Hour'] = df['Date/Time (LST)'].dt.hour

# Define off-peak and peak hours
off_peak_start = 0
off_peak_end = 16
peak_start = 21
peak_end = 16  # Next day

# Filter data for off-peak and peak hours
off_peak_data = df[(df['Hour'] >= off_peak_start) & (df['Hour'] <= off_peak_end)]
peak_data = df[((df['Hour'] >= peak_start) | (df['Hour'] <= peak_end)) & (df['Hour'] != peak_end)]

# Calculate average temperature for each day
off_peak_avg_temp = off_peak_data.groupby('Date')['Temp (°C)'].mean()
peak_avg_temp = peak_data.groupby('Date')['Temp (°C)'].mean()

# Plot the average temperature
plt.figure(figsize=(10, 6))
plt.plot(off_peak_avg_temp.index, off_peak_avg_temp.values, label='Off-Peak Avg Temp', marker='o')
plt.plot(peak_avg_temp.index, peak_avg_temp.values, label='Peak Avg Temp', marker='x')
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.title("Average Temperature during Off-Peak and Peak Hours")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Filter data for January
january_data = df[df['Date/Time (LST)'].dt.month == 1]

# Calculate average temperature for each day in January
off_peak_avg_temp_jan = january_data[(january_data['Hour'] >= off_peak_start) & (january_data['Hour'] <= off_peak_end)].groupby('Date')['Temp (°C)'].mean()
peak_avg_temp_jan = january_data[((january_data['Hour'] >= peak_start) | (january_data['Hour'] <= peak_end)) & (january_data['Hour'] != peak_end)].groupby('Date')['Temp (°C)'].mean()

# Plot the average temperature for January
plt.figure(figsize=(10, 6))
plt.plot(off_peak_avg_temp_jan.index, off_peak_avg_temp_jan.values, label='Off-Peak Avg Temp (January)', marker='o')
plt.plot(peak_avg_temp_jan.index, peak_avg_temp_jan.values, label='Peak Avg Temp (January)', marker='x')
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.title("Average Temperature during Off-Peak and Peak Hours in January")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Assuming you have already loaded the data into the 'df' DataFrame

# Extract the date and time components
df['Date'] = df['Date/Time (LST)'].dt.date
df['Hour'] = df['Date/Time (LST)'].dt.hour

# Define off-peak and peak hours
off_peak_start = 0
off_peak_end = 16
peak_start = 16
peak_end = 21 # Next day

# Filter data for off-peak and peak hours
off_peak_data = df[(df['Hour'] >= off_peak_start) & (df['Hour'] <= off_peak_end)]
peak_data = df[(df['Hour'] >= peak_start) & (df['Hour'] <= peak_end)]

# Calculate average temperature for each day
off_peak_avg_temp = off_peak_data.groupby('Date')['Temp (°C)'].mean()
peak_avg_temp = peak_data.groupby('Date')['Temp (°C)'].mean()

# Create a new DataFrame with adjusted timestamps
combined_df = pd.DataFrame({
    'Date': off_peak_avg_temp.index,
    '10:00 AM Avg Temp': off_peak_avg_temp.values,
    '6:00 PM Avg Temp': peak_avg_temp.values
})

# Create a new DataFrame with adjusted timestamps
combined_df = pd.DataFrame({
    'Date': off_peak_avg_temp.index,
    'Off-Peak Avg Temp': off_peak_avg_temp.values,
    'Peak Avg Temp': peak_avg_temp.values
})

# Rearrange the data to have one row per timestamp
combined_df = combined_df.melt(id_vars=['Date'], value_vars=['Off-Peak Avg Temp', 'Peak Avg Temp'], 
                               var_name='Timestamp', value_name='Temperature (°C)')
# Plot the combined average temperature for each timestamp
plt.figure(figsize=(10, 6))
plt.plot(combined_df['Date'], combined_df['Temperature (°C)'], marker='o')
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.title("Temperature during Off-Peak and Peak Hours")
plt.grid(True)
plt.show()

# %%
# Assuming you have already loaded the data into the 'df' DataFrame

# Extract the date and time components
df['Date'] = df['Date/Time (LST)'].dt.date
df['Hour'] = df['Date/Time (LST)'].dt.hour

# Define off-peak and peak hours
off_peak_start = 0
off_peak_end = 16
peak_start = 16
peak_end = 21

# Filter data for January
january_data = df[df['Date/Time (LST)'].dt.month == 1]

# Filter data for off-peak and peak hours in January
off_peak_data_jan = january_data[(january_data['Hour'] >= off_peak_start) & (january_data['Hour'] <= off_peak_end)]
peak_data_jan = january_data[(january_data['Hour'] >= peak_start) & (january_data['Hour'] <= peak_end)]

# Calculate average temperature for each day in January
off_peak_avg_temp_jan = off_peak_data_jan.groupby('Date')['Temp (°C)'].mean()
peak_avg_temp_jan = peak_data_jan.groupby('Date')['Temp (°C)'].mean()

# Create a new DataFrame with adjusted timestamps
combined_df = pd.DataFrame({
    'Date': off_peak_avg_temp_jan.index,
    'Off-Peak Avg Temp': off_peak_avg_temp_jan.values,
    'Peak Avg Temp': peak_avg_temp_jan.values
})


# Rearrange the data to have one row per timestamp
combined_df = combined_df.melt(id_vars=['Date'], value_vars=['Off-Peak Avg Temp', 'Peak Avg Temp'], 
                               var_name='Timestamp', value_name='Temperature (°C)')
# Plot the combined average temperature for each timestamp
plt.figure(figsize=(10, 6))
plt.plot(combined_df['Date'], combined_df['Temperature (°C)'], marker='o')
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.title("Temperature during Off-Peak and Peak Hours")
plt.grid(True)
plt.show()
