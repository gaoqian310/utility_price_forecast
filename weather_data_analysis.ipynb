# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\gaoqian\AppData\Local\Temp\ipykernel_40552\2369027854.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Read the CSV file into a DataFrame object
df = pd.read_csv("weather_data/Calgary_2020.csv",encoding = "cp1252")

# %%
# View the first 5 rows of the DataFrame
df.head()
# Out:
#    Longitude (x)  Latitude (y)    Station Name  Climate ID   Date/Time (LST)  \
# 0        -114.01         51.12  CALGARY INTL A     3031092  2021-01-01 00:00
# 1        -114.01         51.12  CALGARY INTL A     3031092  2021-01-01 01:00
# 2        -114.01         51.12  CALGARY INTL A     3031092  2021-01-01 02:00
# 3        -114.01         51.12  CALGARY INTL A     3031092  2021-01-01 03:00
# 4        -114.01         51.12  CALGARY INTL A     3031092  2021-01-01 04:00
#
#    Year  Month  Day Time (LST)  Temp (°C)  ... Wind Spd Flag  Visibility (km)  \
# 0  2021      1    1      00:00       -3.2  ...           NaN             24.1
# 1  2021      1    1      01:00        2.5  ...           NaN             24.1
# 2  2021      1    1      02:00        2.0  ...           NaN             24.1
# 3  2021      1    1      03:00        2.4  ...           NaN             24.1
# 4  2021      1    1      04:00        2.4  ...           NaN             24.1
#
#   Visibility Flag  Stn Press (kPa) Stn Press Flag  Hmdx  Hmdx Flag  \
# 0             NaN            88.37            NaN   NaN        NaN
# 1             NaN            88.39            NaN   NaN        NaN
# 2             NaN            88.43            NaN   NaN        NaN
# 3             NaN            88.47            NaN   NaN        NaN
# 4             NaN            88.46            NaN   NaN        NaN
#
#    Wind Chill  Wind Chill Flag  Weather
# 0        -8.0              NaN      NaN
# 1         NaN              NaN      NaN
# 2         NaN              NaN    Clear
# 3         NaN              NaN      NaN
# 4         NaN              NaN      NaN
#
# [5 rows x 30 columns]

# %%
# View the summary statistics of the numerical columns
df.describe()
# Out:
#        Longitude (x)  Latitude (y)  Climate ID    Year        Month  \
# count        8760.00       8760.00      8760.0  8760.0  8760.000000
# mean         -114.01         51.12   3031092.0  2021.0     6.526027
# std             0.00          0.00         0.0     0.0     3.448048
# min          -114.01         51.12   3031092.0  2021.0     1.000000
# 25%          -114.01         51.12   3031092.0  2021.0     4.000000
# 50%          -114.01         51.12   3031092.0  2021.0     7.000000
# 75%          -114.01         51.12   3031092.0  2021.0    10.000000
# max          -114.01         51.12   3031092.0  2021.0    12.000000
#
#                Day    Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# count  8760.000000  8754.000000          8752.000000  8754.000000
# mean     15.720548     5.475326            -3.629913    56.959447
# std       8.796749    12.528264            10.175871    21.012122
# min       1.000000   -32.300000           -35.400000     8.000000
# 25%       8.000000    -1.400000            -9.925000    39.000000
# 50%      16.000000     5.900000            -3.600000    58.000000
# 75%      23.000000    14.300000             4.200000    75.000000
# max      31.000000    36.100000            19.100000    98.000000
#
#        Precip. Amount (mm)  ...  Wind Dir (10s deg)  Wind Dir Flag  \
# count                  0.0  ...         8750.000000            0.0
# mean                   NaN  ...           21.396571            NaN
# std                    NaN  ...           10.205231            NaN
# min                    NaN  ...            0.000000            NaN
# 25%                    NaN  ...           16.000000            NaN
# 50%                    NaN  ...           21.000000            NaN
# 75%                    NaN  ...           30.000000            NaN
# max                    NaN  ...           36.000000            NaN
#
#        Wind Spd (km/h)  Visibility (km)  Visibility Flag  Stn Press (kPa)  \
# count      8755.000000      8756.000000              0.0      8754.000000
# mean         14.086122        30.701405              NaN        88.708967
# std           8.872405        20.173998              NaN         0.712105
# min           0.000000         0.000000              NaN        85.840000
# 25%           8.000000        16.100000              NaN        88.260000
# 50%          12.000000        24.100000              NaN        88.770000
# 75%          19.000000        48.300000              NaN        89.210000
# max          65.000000        72.400000              NaN        90.630000
#
#              Hmdx  Hmdx Flag   Wind Chill  Wind Chill Flag
# count  522.000000        0.0  2583.000000              0.0
# mean    28.312261        NaN   -14.709640              NaN
# std      2.851441        NaN    10.244838              NaN
# min     25.000000        NaN   -43.000000              NaN
# 25%     26.000000        NaN   -22.000000              NaN
# 50%     28.000000        NaN   -11.000000              NaN
# 75%     30.000000        NaN    -6.000000              NaN
# max     37.000000        NaN     0.000000              NaN
#
# [8 rows x 21 columns]

# %%
# View the data types and missing values of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Longitude (x)        8760 non-null   float64
#  1   Latitude (y)         8760 non-null   float64
#  2   Station Name         8760 non-null   object
#  3   Climate ID           8760 non-null   int64
#  4   Date/Time (LST)      8760 non-null   object
#  5   Year                 8760 non-null   int64
#  6   Month                8760 non-null   int64
#  7   Day                  8760 non-null   int64
#  8   Time (LST)           8760 non-null   object
#  9   Temp (°C)            8754 non-null   float64
#  10  Temp Flag            2 non-null      object
#  11  Dew Point Temp (°C)  8752 non-null   float64
#  12  Dew Point Temp Flag  4 non-null      object
#  13  Rel Hum (%)          8754 non-null   float64
#  14  Rel Hum Flag         2 non-null      object
#  15  Precip. Amount (mm)  0 non-null      float64
#  16  Precip. Amount Flag  0 non-null      float64
#  17  Wind Dir (10s deg)   8750 non-null   float64
#  18  Wind Dir Flag        0 non-null      float64
#  19  Wind Spd (km/h)      8755 non-null   float64
#  20  Wind Spd Flag        1 non-null      object
#  21  Visibility (km)      8756 non-null   float64
#  22  Visibility Flag      0 non-null      float64
#  23  Stn Press (kPa)      8754 non-null   float64
#  24  Stn Press Flag       2 non-null      object
#  25  Hmdx                 522 non-null    float64
#  26  Hmdx Flag            0 non-null      float64
#  27  Wind Chill           2583 non-null   float64
#  28  Wind Chill Flag      0 non-null      float64
#  29  Weather              3978 non-null   object
# dtypes: float64(17), int64(4), object(9)
# memory usage: 2.0+ MB

# %%
sns.histplot(df["Temp (°C)"], kde=True)
plt.xlabel("Temperature (°C)")
plt.ylabel("Frequency")
plt.title("Distribution of Temperature in 2020")
plt.show()

# %%
df["Date"] = pd.to_datetime(df[["Year", "Month", "Day"]])

# Group by date and get the maximum temperature
df_max = df.groupby("Date")["Temp (°C)"].max()

# Group by date and get the minimum temperature
df_min = df.groupby("Date")["Temp (°C)"].min()

# Plot the data
plt.plot(df_max, color='r', label='Maximum Temperature')
plt.plot(df_min, color='b', label='Minimum Temperature')
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.title("Maximum and Minimum Temperature of the Day in 2020")
plt.grid()
plt.legend()
plt.show()
